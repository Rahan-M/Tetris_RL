# %%
# !rm -rf /content/Tetris_RL
# !rm -rf /content/tetris_sb3_logs
# !rm /content/tetris_register.py
# !rm /content/Tetris_RL.zip

# %%
# !pip install gymnasium stable-baselines3[extra] pygame
# Out:
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.12/dist-packages (1.2.2)
# Requirement already satisfied: pygame in /usr/local/lib/python3.12/dist-packages (2.6.1)
# Collecting stable-baselines3[extra]
#   Downloading stable_baselines3-2.7.1-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]) (2.9.0+cu126)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]) (3.10.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]) (4.12.0.88)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]) (2.19.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]) (5.9.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]) (4.67.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]) (13.9.4)
# Requirement already satisfied: ale-py>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]) (0.11.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]) (11.3.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.76.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.10)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (25.0)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (5.29.5)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (75.2.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.1.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.20.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3[extra]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3[extra]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3[extra]) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3[extra]) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3[extra]) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3[extra]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3[extra]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3[extra]) (2025.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->stable-baselines3[extra]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->stable-baselines3[extra]) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (3.0.3)
# Downloading stable_baselines3-2.7.1-py3-none-any.whl (188 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.0/188.0 kB 6.0 MB/s eta 0:00:00
# Installing collected packages: stable-baselines3
# Successfully installed stable-baselines3-2.7.1

# %%
# from google.colab import files
# uploaded = files.upload()

# %%
# !unzip Tetris_RL.zip -d .

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import sys
sys.path.append("/content/drive/MyDrive/Tetris_RL")
# add project to python path, allows python to find the files while importing

# %%
from tetris.tetris_env import TetrisGymEnv
from tetris.tetris_engine import TetrisEngine

# %%
# sample=TetrisGymEnv(observation_type="board_and_heuristics")
# print(sample.survival_reward)

# %%
# %%writefile tetris_register.py
from gymnasium.envs.registration import register

register(
    id="Tetris-v0",
    entry_point="tetris.tetris_env:TetrisGymEnv",
)
# Out:
# Writing tetris_register.py

# %%
import tetris_register

# %%
import os
import glob
from stable_baselines3 import DQN
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import CheckpointCallback, EvalCallback
import gymnasium as gym
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
# obj=TetrisGymEnv(observation_type="board_and_heuristics")
# print(obj.lines_cleared_reward, obj.step_penalty)

# %%
# Create environment factory so DummyVecEnv can make it
def make_env():
    def _init():
        env = gym.make("Tetris-v0", observation_type="board_and_heuristics")
        # force the correct observation type
        env = Monitor(env)
        # print(f"step penalty = {env.step_penalty}")
        return env
    return _init

# %%
# PARAMETERS - same as before
ENV_ID = "Tetris-v0"
TIMESTEPS = 3_000_000
EVAL_FREQ = 50_000
CHECKPOINT_FREQ = 100_000
LOG_DIR = "/content/drive/MyDrive/tetris_sb3_logs_V7"

# Find the latest checkpoint
checkpoint_dir = os.path.join(LOG_DIR, "checkpoints")
checkpoint_files = glob.glob(os.path.join(checkpoint_dir, "tetris_dqn_*.zip"))

# Recreate environments
vec_env = DummyVecEnv([make_env()])
vec_env = VecNormalize(vec_env, norm_obs=True, norm_reward=False, clip_obs=10.0)

eval_env = DummyVecEnv([make_env()])
eval_env = VecNormalize(eval_env, norm_obs=True, norm_reward=False, clip_obs=10.0)
eval_env.training = False
eval_env.norm_reward = False

from stable_baselines3.common.callbacks import BaseCallback

class SaveReplayBufferCallback(BaseCallback):
    def __init__(self, save_path: str, save_freq: int, verbose=1):
        super().__init__(verbose)
        self.save_path = save_path
        self.save_freq = save_freq

    def _on_step(self) -> bool:
        if self.n_calls % self.save_freq != 0:
            return True

        path = os.path.join(self.save_path, "replay_buffer.pkl")
        self.model.save_replay_buffer(path)

        if self.verbose > 0:
            print(f"Saved replay buffer to {path}")

        return True

class SaveVecNormalizeCallback(BaseCallback):
    def __init__(self, save_path: str, save_freq: int = 0, verbose=1):
        super().__init__(verbose)
        self.save_path = save_path
        self.save_freq = save_freq # Add frequency control

    def _init_callback(self) -> None:
        # Create folder if it doesn't exist
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self) -> bool:
        # If save_freq is 0, we assume this callback is being called
        # by another callback (like EvalCallback), so we save every time it's called.
        # If save_freq > 0, we check the step count.

        if self.save_freq > 0:
            if self.n_calls % self.save_freq != 0:
                return True

        path = os.path.join(self.save_path, "vecnormalize.pkl")

        # SB3 environments are wrapped. We need to access the original VecNormalize
        # usually usually accessible via self.training_env
        self.training_env.save(path)

        if self.verbose > 1:
            print(f"Saved VecNormalize to {path}")
        return True

if checkpoint_files:
    # Sort by modification time to get the latest
    latest_checkpoint = max(checkpoint_files, key=os.path.getmtime)
    print(f"Found latest checkpoint: {latest_checkpoint}")

    # Extract the step number from filename
    import re
    match = re.search(r'tetris_dqn_(\d+)_steps', os.path.basename(latest_checkpoint))
    if match:
        completed_steps = int(match.group(1))
        remaining_steps = TIMESTEPS - completed_steps
        print(f"Completed steps: {completed_steps}, Remaining: {remaining_steps}")
    else:
        remaining_steps = TIMESTEPS
        print("Could not parse step count, training full duration")

    # Load the model
    model = DQN.load(
        latest_checkpoint,
        env=vec_env,
        device="auto"
    )

    replay_path = os.path.join(checkpoint_dir, "replay_buffer.pkl")
    if os.path.exists(replay_path):
        model.load_replay_buffer(replay_path)
        print("Replay buffer loaded")
    else:
        print("No replay buffer found, starting with empty buffer")

    # Load VecNormalize stats if they exist
    vecnorm_path = os.path.join(checkpoint_dir, "vecnormalize.pkl")
    if os.path.exists(vecnorm_path):
        vec_env = VecNormalize.load(vecnorm_path, vec_env)
        print(f"Loaded VecNormalize stats from {vecnorm_path}")

        # Sync eval env
        eval_env = VecNormalize.load(vecnorm_path, eval_env)
        eval_env.training = False
        eval_env.norm_reward = False
    else:
        print("No VecNormalize stats found, using fresh normalization")

    # Update model's environment
    model.set_env(vec_env)

    print("Resuming training...")

else:
    print("No checkpoints found, starting fresh training")
    remaining_steps = TIMESTEPS

    # Create new model with your custom feature extractor
    from stable_baselines3.common.torch_layers import BaseFeaturesExtractor
    import torch as th
    import torch.nn as nn

    class TetrisCombinedExtractor(BaseFeaturesExtractor):
        def __init__(self, observation_space, features_dim: int = 512):
            super().__init__(observation_space, features_dim)

            board_shape = observation_space['board'].shape
            feature_shape = observation_space['features'].shape

            self.cnn = nn.Sequential(
                nn.Conv2d(board_shape[0], 32, kernel_size=3, stride=1, padding=1),
                nn.ReLU(),
                nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),
                nn.ReLU(),
                nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1),
                nn.ReLU(),
                nn.Flatten()
            )

            with th.no_grad():
                dummy_board = th.zeros(1, *board_shape, dtype=th.float32)
                conv_out = self.cnn(dummy_board).shape[1]

            self.mlpf = nn.Sequential(
                nn.Linear(feature_shape[0], 64),
                nn.ReLU(),
                nn.Linear(64, 64),
                nn.ReLU(),
            )

            combined_input_size = conv_out + 64
            self.final_mlp = nn.Sequential(
                nn.Linear(combined_input_size, 512),
                nn.ReLU(),
                nn.Linear(512, features_dim),
                nn.ReLU()
            )

            self._features_dim = features_dim

        def forward(self, observations):
            board = observations['board']
            feats = observations['features']

            if not isinstance(board, th.Tensor):
                board = th.tensor(board).to(next(self.parameters()).device)
            if not isinstance(feats, th.Tensor):
                feats = th.tensor(feats).to(next(self.parameters()).device)

            conv_out = self.cnn(board)
            mlp_out = self.mlpf(feats)

            combined = th.cat([conv_out, mlp_out], dim=1)
            return self.final_mlp(combined)

    policy_kwargs = dict(
        features_extractor_class=TetrisCombinedExtractor,
        features_extractor_kwargs=dict(features_dim=512),
    )

    model = DQN(
        policy="MultiInputPolicy",
        env=vec_env,
        learning_rate=1e-4,
        buffer_size=1_000_000,
        learning_starts=50_000,
        batch_size=256,
        gamma=0.99,
        train_freq=(4, "step"),
        target_update_interval=5000,
        exploration_fraction=0.6,
        exploration_final_eps=0.05,
        policy_kwargs=policy_kwargs,
        verbose=1,
        tensorboard_log=LOG_DIR,
        device="auto",
    )

# Recreate callbacks
checkpoint_cb = CheckpointCallback(
    save_freq=CHECKPOINT_FREQ,
    save_path=checkpoint_dir,
    name_prefix="tetris_dqn"
)

save_replay_cb = SaveReplayBufferCallback(
    save_path=checkpoint_dir,
    save_freq=CHECKPOINT_FREQ
)

save_vec_best = SaveVecNormalizeCallback(
    save_path=os.path.join(LOG_DIR, "best_model")
)

save_vec_periodic = SaveVecNormalizeCallback(
    save_path=checkpoint_dir,
    save_freq=CHECKPOINT_FREQ
)

eval_cb = EvalCallback(
    eval_env,
    best_model_save_path=os.path.join(LOG_DIR, "best_model"),
    log_path=os.path.join(LOG_DIR, "eval_logs"),
    eval_freq=EVAL_FREQ,
    n_eval_episodes=8,
    deterministic=True,
    render=False,
    callback_on_new_best=save_vec_best
)

# Resume/Continue training
model.learn(
    total_timesteps=remaining_steps,
    callback=[checkpoint_cb, eval_cb, save_vec_periodic, save_replay_cb],
    reset_num_timesteps=False  # Important: don't reset the step counter
)

# Save final model
model.save(os.path.join(LOG_DIR, "tetris_dqn_final"))
vec_env.save(os.path.join(LOG_DIR, "vecnormalize.pkl"))

print("Training complete. Artifacts saved to:", LOG_DIR)
# Out:
# /usr/local/lib/python3.12/dist-packages/gymnasium/envs/registration.py:480: UserWarning: WARN: The environment creator metadata doesn't include `render_modes`, contains: ['render.modes']
#   logger.warn(
# Found latest checkpoint: /content/drive/MyDrive/tetris_sb3_logs_V7/checkpoints/tetris_dqn_2500000_steps.zip
# Completed steps: 2500000, Remaining: 500000
# Loaded VecNormalize stats from /content/drive/MyDrive/tetris_sb3_logs_V7/checkpoints/vecnormalize.pkl
# Resuming training...
# Logging to /content/drive/MyDrive/tetris_sb3_logs_V7/DQN_0
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Streaming output truncated to the last 5000 lines.
# |    learning_rate    | 0.0001   |
# |    loss             | 45.2     |
# |    n_updates        | 614016   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 193      |
# |    ep_rew_mean      | -37      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23556    |
# |    fps              | 145      |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 2506858  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.039    |
# |    n_updates        | 614212   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 191      |
# |    ep_rew_mean      | -36.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23560    |
# |    fps              | 145      |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 2507567  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0223   |
# |    n_updates        | 614389   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 191      |
# |    ep_rew_mean      | -36.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23564    |
# |    fps              | 146      |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 2508308  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.013    |
# |    n_updates        | 614574   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 188      |
# |    ep_rew_mean      | -36.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23568    |
# |    fps              | 146      |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 2508967  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0124   |
# |    n_updates        | 614739   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 186      |
# |    ep_rew_mean      | -36.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23572    |
# |    fps              | 146      |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 2509651  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0125   |
# |    n_updates        | 614910   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 182      |
# |    ep_rew_mean      | -36.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23576    |
# |    fps              | 147      |
# |    time_elapsed     | 69       |
# |    total_timesteps  | 2510206  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.8      |
# |    n_updates        | 615049   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -36.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23580    |
# |    fps              | 147      |
# |    time_elapsed     | 72       |
# |    total_timesteps  | 2510770  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0702   |
# |    n_updates        | 615190   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 178      |
# |    ep_rew_mean      | -36.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23584    |
# |    fps              | 147      |
# |    time_elapsed     | 78       |
# |    total_timesteps  | 2511597  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0326   |
# |    n_updates        | 615397   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 176      |
# |    ep_rew_mean      | -36.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23588    |
# |    fps              | 148      |
# |    time_elapsed     | 82       |
# |    total_timesteps  | 2512215  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0265   |
# |    n_updates        | 615551   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 171      |
# |    ep_rew_mean      | -36.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23592    |
# |    fps              | 148      |
# |    time_elapsed     | 85       |
# |    total_timesteps  | 2512681  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 96.5     |
# |    n_updates        | 615668   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 167      |
# |    ep_rew_mean      | -36.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23596    |
# |    fps              | 147      |
# |    time_elapsed     | 90       |
# |    total_timesteps  | 2513342  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0299   |
# |    n_updates        | 615833   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 165      |
# |    ep_rew_mean      | -36.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23600    |
# |    fps              | 147      |
# |    time_elapsed     | 94       |
# |    total_timesteps  | 2513981  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0143   |
# |    n_updates        | 615993   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 162      |
# |    ep_rew_mean      | -36.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23604    |
# |    fps              | 148      |
# |    time_elapsed     | 98       |
# |    total_timesteps  | 2514660  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0166   |
# |    n_updates        | 616162   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 159      |
# |    ep_rew_mean      | -36.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23608    |
# |    fps              | 148      |
# |    time_elapsed     | 103      |
# |    total_timesteps  | 2515358  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.146    |
# |    n_updates        | 616337   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 158      |
# |    ep_rew_mean      | -36.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23612    |
# |    fps              | 148      |
# |    time_elapsed     | 107      |
# |    total_timesteps  | 2515886  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0806   |
# |    n_updates        | 616469   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 157      |
# |    ep_rew_mean      | -36.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23616    |
# |    fps              | 148      |
# |    time_elapsed     | 110      |
# |    total_timesteps  | 2516359  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0458   |
# |    n_updates        | 616587   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 159      |
# |    ep_rew_mean      | -36.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23620    |
# |    fps              | 149      |
# |    time_elapsed     | 115      |
# |    total_timesteps  | 2517147  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0315   |
# |    n_updates        | 616784   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 159      |
# |    ep_rew_mean      | -36.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23624    |
# |    fps              | 148      |
# |    time_elapsed     | 118      |
# |    total_timesteps  | 2517574  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0491   |
# |    n_updates        | 616891   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 159      |
# |    ep_rew_mean      | -36.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23628    |
# |    fps              | 149      |
# |    time_elapsed     | 121      |
# |    total_timesteps  | 2518177  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0359   |
# |    n_updates        | 617042   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 159      |
# |    ep_rew_mean      | -36.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23632    |
# |    fps              | 149      |
# |    time_elapsed     | 125      |
# |    total_timesteps  | 2518718  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0209   |
# |    n_updates        | 617177   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 159      |
# |    ep_rew_mean      | -37.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23636    |
# |    fps              | 149      |
# |    time_elapsed     | 129      |
# |    total_timesteps  | 2519360  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.197    |
# |    n_updates        | 617337   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 158      |
# |    ep_rew_mean      | -37.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23640    |
# |    fps              | 149      |
# |    time_elapsed     | 133      |
# |    total_timesteps  | 2519907  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.02     |
# |    n_updates        | 617474   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 158      |
# |    ep_rew_mean      | -37.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23644    |
# |    fps              | 149      |
# |    time_elapsed     | 136      |
# |    total_timesteps  | 2520477  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.1      |
# |    n_updates        | 617617   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 158      |
# |    ep_rew_mean      | -37.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23648    |
# |    fps              | 149      |
# |    time_elapsed     | 141      |
# |    total_timesteps  | 2521138  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0414   |
# |    n_updates        | 617782   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 158      |
# |    ep_rew_mean      | -37.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23652    |
# |    fps              | 149      |
# |    time_elapsed     | 146      |
# |    total_timesteps  | 2521894  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0331   |
# |    n_updates        | 617971   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 155      |
# |    ep_rew_mean      | -37.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23656    |
# |    fps              | 149      |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 2522381  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0294   |
# |    n_updates        | 618093   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 155      |
# |    ep_rew_mean      | -37.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23660    |
# |    fps              | 150      |
# |    time_elapsed     | 153      |
# |    total_timesteps  | 2523061  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0469   |
# |    n_updates        | 618263   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 154      |
# |    ep_rew_mean      | -37.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23664    |
# |    fps              | 150      |
# |    time_elapsed     | 158      |
# |    total_timesteps  | 2523735  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0131   |
# |    n_updates        | 618431   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 154      |
# |    ep_rew_mean      | -37.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23668    |
# |    fps              | 150      |
# |    time_elapsed     | 161      |
# |    total_timesteps  | 2524326  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0217   |
# |    n_updates        | 618579   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 152      |
# |    ep_rew_mean      | -37.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23672    |
# |    fps              | 150      |
# |    time_elapsed     | 165      |
# |    total_timesteps  | 2524846  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0437   |
# |    n_updates        | 618709   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 153      |
# |    ep_rew_mean      | -37.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23676    |
# |    fps              | 150      |
# |    time_elapsed     | 169      |
# |    total_timesteps  | 2525475  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0702   |
# |    n_updates        | 618866   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 154      |
# |    ep_rew_mean      | -37.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23680    |
# |    fps              | 150      |
# |    time_elapsed     | 173      |
# |    total_timesteps  | 2526131  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0709   |
# |    n_updates        | 619030   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 151      |
# |    ep_rew_mean      | -37.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23684    |
# |    fps              | 150      |
# |    time_elapsed     | 177      |
# |    total_timesteps  | 2526703  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0484   |
# |    n_updates        | 619173   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 154      |
# |    ep_rew_mean      | -37.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23688    |
# |    fps              | 148      |
# |    time_elapsed     | 185      |
# |    total_timesteps  | 2527616  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0561   |
# |    n_updates        | 619401   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 156      |
# |    ep_rew_mean      | -37.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23692    |
# |    fps              | 148      |
# |    time_elapsed     | 189      |
# |    total_timesteps  | 2528242  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0543   |
# |    n_updates        | 619558   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 154      |
# |    ep_rew_mean      | -37.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23696    |
# |    fps              | 149      |
# |    time_elapsed     | 192      |
# |    total_timesteps  | 2528737  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0262   |
# |    n_updates        | 619682   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 154      |
# |    ep_rew_mean      | -37.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23700    |
# |    fps              | 148      |
# |    time_elapsed     | 197      |
# |    total_timesteps  | 2529382  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0273   |
# |    n_updates        | 619843   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 153      |
# |    ep_rew_mean      | -37.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23704    |
# |    fps              | 149      |
# |    time_elapsed     | 200      |
# |    total_timesteps  | 2529917  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0442   |
# |    n_updates        | 619977   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 151      |
# |    ep_rew_mean      | -37.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23708    |
# |    fps              | 149      |
# |    time_elapsed     | 203      |
# |    total_timesteps  | 2530409  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.104    |
# |    n_updates        | 620100   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 152      |
# |    ep_rew_mean      | -37.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23712    |
# |    fps              | 149      |
# |    time_elapsed     | 207      |
# |    total_timesteps  | 2531083  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.053    |
# |    n_updates        | 620268   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 154      |
# |    ep_rew_mean      | -37.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23716    |
# |    fps              | 149      |
# |    time_elapsed     | 212      |
# |    total_timesteps  | 2531753  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0474   |
# |    n_updates        | 620436   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 151      |
# |    ep_rew_mean      | -37.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23720    |
# |    fps              | 149      |
# |    time_elapsed     | 215      |
# |    total_timesteps  | 2532277  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0303   |
# |    n_updates        | 620567   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 155      |
# |    ep_rew_mean      | -37.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23724    |
# |    fps              | 149      |
# |    time_elapsed     | 220      |
# |    total_timesteps  | 2533066  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.038    |
# |    n_updates        | 620764   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 155      |
# |    ep_rew_mean      | -37.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23728    |
# |    fps              | 149      |
# |    time_elapsed     | 225      |
# |    total_timesteps  | 2533702  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.114    |
# |    n_updates        | 620923   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 157      |
# |    ep_rew_mean      | -37.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23732    |
# |    fps              | 149      |
# |    time_elapsed     | 229      |
# |    total_timesteps  | 2534390  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.049    |
# |    n_updates        | 621095   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 155      |
# |    ep_rew_mean      | -37.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23736    |
# |    fps              | 149      |
# |    time_elapsed     | 232      |
# |    total_timesteps  | 2534906  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0206   |
# |    n_updates        | 621224   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 158      |
# |    ep_rew_mean      | -37.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23740    |
# |    fps              | 149      |
# |    time_elapsed     | 238      |
# |    total_timesteps  | 2535673  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0914   |
# |    n_updates        | 621416   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 158      |
# |    ep_rew_mean      | -37.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23744    |
# |    fps              | 149      |
# |    time_elapsed     | 242      |
# |    total_timesteps  | 2536326  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.1      |
# |    n_updates        | 621579   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 159      |
# |    ep_rew_mean      | -37.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23748    |
# |    fps              | 150      |
# |    time_elapsed     | 246      |
# |    total_timesteps  | 2537064  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.049    |
# |    n_updates        | 621763   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 159      |
# |    ep_rew_mean      | -37.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23752    |
# |    fps              | 149      |
# |    time_elapsed     | 252      |
# |    total_timesteps  | 2537824  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.053    |
# |    n_updates        | 621953   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 163      |
# |    ep_rew_mean      | -37.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23756    |
# |    fps              | 149      |
# |    time_elapsed     | 258      |
# |    total_timesteps  | 2538650  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0566   |
# |    n_updates        | 622160   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 164      |
# |    ep_rew_mean      | -37.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23760    |
# |    fps              | 149      |
# |    time_elapsed     | 264      |
# |    total_timesteps  | 2539499  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0303   |
# |    n_updates        | 622372   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 166      |
# |    ep_rew_mean      | -37.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23764    |
# |    fps              | 149      |
# |    time_elapsed     | 268      |
# |    total_timesteps  | 2540286  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.108    |
# |    n_updates        | 622569   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 167      |
# |    ep_rew_mean      | -37.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23768    |
# |    fps              | 149      |
# |    time_elapsed     | 274      |
# |    total_timesteps  | 2541047  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0773   |
# |    n_updates        | 622759   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 170      |
# |    ep_rew_mean      | -37.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23772    |
# |    fps              | 149      |
# |    time_elapsed     | 280      |
# |    total_timesteps  | 2541877  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0489   |
# |    n_updates        | 622967   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 172      |
# |    ep_rew_mean      | -37.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23776    |
# |    fps              | 149      |
# |    time_elapsed     | 286      |
# |    total_timesteps  | 2542664  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.112    |
# |    n_updates        | 623163   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 174      |
# |    ep_rew_mean      | -37.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23780    |
# |    fps              | 148      |
# |    time_elapsed     | 292      |
# |    total_timesteps  | 2543500  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0411   |
# |    n_updates        | 623372   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 177      |
# |    ep_rew_mean      | -38.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23784    |
# |    fps              | 149      |
# |    time_elapsed     | 297      |
# |    total_timesteps  | 2544377  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0248   |
# |    n_updates        | 623592   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 176      |
# |    ep_rew_mean      | -38.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23788    |
# |    fps              | 149      |
# |    time_elapsed     | 303      |
# |    total_timesteps  | 2545176  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.118    |
# |    n_updates        | 623791   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 178      |
# |    ep_rew_mean      | -38.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23792    |
# |    fps              | 148      |
# |    time_elapsed     | 309      |
# |    total_timesteps  | 2546014  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.123    |
# |    n_updates        | 624001   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 183      |
# |    ep_rew_mean      | -38.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23796    |
# |    fps              | 147      |
# |    time_elapsed     | 318      |
# |    total_timesteps  | 2547002  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0543   |
# |    n_updates        | 624248   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 185      |
# |    ep_rew_mean      | -38.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23800    |
# |    fps              | 147      |
# |    time_elapsed     | 323      |
# |    total_timesteps  | 2547846  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0243   |
# |    n_updates        | 624459   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 187      |
# |    ep_rew_mean      | -38.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23804    |
# |    fps              | 147      |
# |    time_elapsed     | 328      |
# |    total_timesteps  | 2548630  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0454   |
# |    n_updates        | 624655   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 191      |
# |    ep_rew_mean      | -39      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23808    |
# |    fps              | 148      |
# |    time_elapsed     | 334      |
# |    total_timesteps  | 2549541  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0204   |
# |    n_updates        | 624883   |
# ----------------------------------
# Eval num_timesteps=2550000, episode_reward=-36.84 +/- 4.40
# Episode length: 253.25 +/- 42.53
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 253      |
# |    mean_reward      | -36.8    |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 2550000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0271   |
# |    n_updates        | 624997   |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 193      |
# |    ep_rew_mean      | -39.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23812    |
# |    fps              | 145      |
# |    time_elapsed     | 347      |
# |    total_timesteps  | 2550394  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0699   |
# |    n_updates        | 625096   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 195      |
# |    ep_rew_mean      | -39.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23816    |
# |    fps              | 144      |
# |    time_elapsed     | 355      |
# |    total_timesteps  | 2551283  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.047    |
# |    n_updates        | 625318   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | -39.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23820    |
# |    fps              | 144      |
# |    time_elapsed     | 361      |
# |    total_timesteps  | 2552142  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.029    |
# |    n_updates        | 625533   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -39.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23824    |
# |    fps              | 144      |
# |    time_elapsed     | 366      |
# |    total_timesteps  | 2553016  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0365   |
# |    n_updates        | 625751   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 202      |
# |    ep_rew_mean      | -39.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23828    |
# |    fps              | 144      |
# |    time_elapsed     | 372      |
# |    total_timesteps  | 2553916  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0312   |
# |    n_updates        | 625976   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 205      |
# |    ep_rew_mean      | -39.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23832    |
# |    fps              | 144      |
# |    time_elapsed     | 378      |
# |    total_timesteps  | 2554869  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.033    |
# |    n_updates        | 626215   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 209      |
# |    ep_rew_mean      | -39.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23836    |
# |    fps              | 144      |
# |    time_elapsed     | 385      |
# |    total_timesteps  | 2555824  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0388   |
# |    n_updates        | 626453   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 209      |
# |    ep_rew_mean      | -39.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23840    |
# |    fps              | 145      |
# |    time_elapsed     | 390      |
# |    total_timesteps  | 2556615  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0335   |
# |    n_updates        | 626651   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 212      |
# |    ep_rew_mean      | -39.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23844    |
# |    fps              | 145      |
# |    time_elapsed     | 396      |
# |    total_timesteps  | 2557562  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0342   |
# |    n_updates        | 626888   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 214      |
# |    ep_rew_mean      | -40.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23848    |
# |    fps              | 145      |
# |    time_elapsed     | 402      |
# |    total_timesteps  | 2558453  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0211   |
# |    n_updates        | 627111   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 215      |
# |    ep_rew_mean      | -40.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23852    |
# |    fps              | 145      |
# |    time_elapsed     | 407      |
# |    total_timesteps  | 2559317  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0186   |
# |    n_updates        | 627327   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 215      |
# |    ep_rew_mean      | -40      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23856    |
# |    fps              | 145      |
# |    time_elapsed     | 413      |
# |    total_timesteps  | 2560162  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0505   |
# |    n_updates        | 627538   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 214      |
# |    ep_rew_mean      | -40.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23860    |
# |    fps              | 145      |
# |    time_elapsed     | 418      |
# |    total_timesteps  | 2560926  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0486   |
# |    n_updates        | 627729   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 215      |
# |    ep_rew_mean      | -40.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23864    |
# |    fps              | 145      |
# |    time_elapsed     | 423      |
# |    total_timesteps  | 2561772  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0314   |
# |    n_updates        | 627940   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 215      |
# |    ep_rew_mean      | -40.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23868    |
# |    fps              | 145      |
# |    time_elapsed     | 428      |
# |    total_timesteps  | 2562582  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0276   |
# |    n_updates        | 628143   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 215      |
# |    ep_rew_mean      | -40.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23872    |
# |    fps              | 145      |
# |    time_elapsed     | 434      |
# |    total_timesteps  | 2563411  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0305   |
# |    n_updates        | 628350   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 216      |
# |    ep_rew_mean      | -40.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23876    |
# |    fps              | 145      |
# |    time_elapsed     | 439      |
# |    total_timesteps  | 2564216  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0408   |
# |    n_updates        | 628551   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 216      |
# |    ep_rew_mean      | -40.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23880    |
# |    fps              | 146      |
# |    time_elapsed     | 445      |
# |    total_timesteps  | 2565053  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0527   |
# |    n_updates        | 628761   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 215      |
# |    ep_rew_mean      | -40.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23884    |
# |    fps              | 146      |
# |    time_elapsed     | 450      |
# |    total_timesteps  | 2565917  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0361   |
# |    n_updates        | 628977   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 216      |
# |    ep_rew_mean      | -40.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23888    |
# |    fps              | 146      |
# |    time_elapsed     | 456      |
# |    total_timesteps  | 2566805  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0235   |
# |    n_updates        | 629199   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 217      |
# |    ep_rew_mean      | -39.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23892    |
# |    fps              | 146      |
# |    time_elapsed     | 462      |
# |    total_timesteps  | 2567716  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.029    |
# |    n_updates        | 629426   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 217      |
# |    ep_rew_mean      | -39.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23896    |
# |    fps              | 146      |
# |    time_elapsed     | 469      |
# |    total_timesteps  | 2568749  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0216   |
# |    n_updates        | 629685   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 218      |
# |    ep_rew_mean      | -39.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23900    |
# |    fps              | 146      |
# |    time_elapsed     | 475      |
# |    total_timesteps  | 2569648  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.034    |
# |    n_updates        | 629909   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 220      |
# |    ep_rew_mean      | -39.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 23904    |
# |    fps              | 146      |
# |    time_elapsed     | 481      |
# |    total_timesteps  | 2570599  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0456   |
# |    n_updates        | 630147   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 219      |
# |    ep_rew_mean      | -39.9    |
# |    exploration_rate | 0.05     |
# ...
# |    time_elapsed     | 1714     |
# |    total_timesteps  | 2759079  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0254   |
# |    n_updates        | 677267   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 231      |
# |    ep_rew_mean      | -37      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24748    |
# |    fps              | 151      |
# |    time_elapsed     | 1720     |
# |    total_timesteps  | 2759998  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0332   |
# |    n_updates        | 677497   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 232      |
# |    ep_rew_mean      | -37      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24752    |
# |    fps              | 151      |
# |    time_elapsed     | 1727     |
# |    total_timesteps  | 2760976  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0264   |
# |    n_updates        | 677741   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 230      |
# |    ep_rew_mean      | -37.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24756    |
# |    fps              | 151      |
# |    time_elapsed     | 1732     |
# |    total_timesteps  | 2761837  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.022    |
# |    n_updates        | 677957   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 231      |
# |    ep_rew_mean      | -37.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24760    |
# |    fps              | 151      |
# |    time_elapsed     | 1738     |
# |    total_timesteps  | 2762732  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0347   |
# |    n_updates        | 678180   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 233      |
# |    ep_rew_mean      | -37      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24764    |
# |    fps              | 151      |
# |    time_elapsed     | 1744     |
# |    total_timesteps  | 2763705  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0168   |
# |    n_updates        | 678424   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 231      |
# |    ep_rew_mean      | -37.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24768    |
# |    fps              | 151      |
# |    time_elapsed     | 1750     |
# |    total_timesteps  | 2764562  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0284   |
# |    n_updates        | 678638   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 231      |
# |    ep_rew_mean      | -37.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24772    |
# |    fps              | 151      |
# |    time_elapsed     | 1756     |
# |    total_timesteps  | 2765528  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0199   |
# |    n_updates        | 678879   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 230      |
# |    ep_rew_mean      | -37.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24776    |
# |    fps              | 151      |
# |    time_elapsed     | 1762     |
# |    total_timesteps  | 2766434  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0207   |
# |    n_updates        | 679106   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 230      |
# |    ep_rew_mean      | -37.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24780    |
# |    fps              | 151      |
# |    time_elapsed     | 1767     |
# |    total_timesteps  | 2767302  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0241   |
# |    n_updates        | 679323   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 229      |
# |    ep_rew_mean      | -37.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24784    |
# |    fps              | 151      |
# |    time_elapsed     | 1773     |
# |    total_timesteps  | 2768171  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0296   |
# |    n_updates        | 679540   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 227      |
# |    ep_rew_mean      | -38.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24788    |
# |    fps              | 151      |
# |    time_elapsed     | 1778     |
# |    total_timesteps  | 2768959  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0229   |
# |    n_updates        | 679737   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 227      |
# |    ep_rew_mean      | -38.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24792    |
# |    fps              | 151      |
# |    time_elapsed     | 1783     |
# |    total_timesteps  | 2769884  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0198   |
# |    n_updates        | 679968   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 226      |
# |    ep_rew_mean      | -38.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24796    |
# |    fps              | 151      |
# |    time_elapsed     | 1788     |
# |    total_timesteps  | 2770623  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0433   |
# |    n_updates        | 680153   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 225      |
# |    ep_rew_mean      | -38.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24800    |
# |    fps              | 151      |
# |    time_elapsed     | 1794     |
# |    total_timesteps  | 2771452  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0218   |
# |    n_updates        | 680360   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 225      |
# |    ep_rew_mean      | -38.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24804    |
# |    fps              | 151      |
# |    time_elapsed     | 1799     |
# |    total_timesteps  | 2772329  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0181   |
# |    n_updates        | 680580   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 226      |
# |    ep_rew_mean      | -38.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24808    |
# |    fps              | 151      |
# |    time_elapsed     | 1805     |
# |    total_timesteps  | 2773279  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0239   |
# |    n_updates        | 680817   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 224      |
# |    ep_rew_mean      | -38.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24812    |
# |    fps              | 151      |
# |    time_elapsed     | 1810     |
# |    total_timesteps  | 2774049  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0241   |
# |    n_updates        | 681010   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 223      |
# |    ep_rew_mean      | -38.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24816    |
# |    fps              | 151      |
# |    time_elapsed     | 1816     |
# |    total_timesteps  | 2774914  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0305   |
# |    n_updates        | 681226   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 224      |
# |    ep_rew_mean      | -38.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24820    |
# |    fps              | 151      |
# |    time_elapsed     | 1822     |
# |    total_timesteps  | 2775877  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0202   |
# |    n_updates        | 681467   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 224      |
# |    ep_rew_mean      | -38.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24824    |
# |    fps              | 151      |
# |    time_elapsed     | 1828     |
# |    total_timesteps  | 2776757  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0154   |
# |    n_updates        | 681687   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 223      |
# |    ep_rew_mean      | -38.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24828    |
# |    fps              | 151      |
# |    time_elapsed     | 1833     |
# |    total_timesteps  | 2777603  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0267   |
# |    n_updates        | 681898   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 222      |
# |    ep_rew_mean      | -38.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24832    |
# |    fps              | 151      |
# |    time_elapsed     | 1839     |
# |    total_timesteps  | 2778443  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0214   |
# |    n_updates        | 682108   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 221      |
# |    ep_rew_mean      | -38.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24836    |
# |    fps              | 151      |
# |    time_elapsed     | 1844     |
# |    total_timesteps  | 2779313  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0197   |
# |    n_updates        | 682326   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 220      |
# |    ep_rew_mean      | -38      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24840    |
# |    fps              | 151      |
# |    time_elapsed     | 1849     |
# |    total_timesteps  | 2780175  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0331   |
# |    n_updates        | 682541   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 220      |
# |    ep_rew_mean      | -38.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24844    |
# |    fps              | 151      |
# |    time_elapsed     | 1855     |
# |    total_timesteps  | 2781086  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0206   |
# |    n_updates        | 682769   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 220      |
# |    ep_rew_mean      | -38.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24848    |
# |    fps              | 151      |
# |    time_elapsed     | 1861     |
# |    total_timesteps  | 2781994  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0251   |
# |    n_updates        | 682996   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 218      |
# |    ep_rew_mean      | -38.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24852    |
# |    fps              | 151      |
# |    time_elapsed     | 1866     |
# |    total_timesteps  | 2782811  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0202   |
# |    n_updates        | 683200   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 218      |
# |    ep_rew_mean      | -38.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24856    |
# |    fps              | 151      |
# |    time_elapsed     | 1872     |
# |    total_timesteps  | 2783659  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0216   |
# |    n_updates        | 683412   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 218      |
# |    ep_rew_mean      | -38.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24860    |
# |    fps              | 151      |
# |    time_elapsed     | 1878     |
# |    total_timesteps  | 2784551  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0327   |
# |    n_updates        | 683635   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 218      |
# |    ep_rew_mean      | -38.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24864    |
# |    fps              | 151      |
# |    time_elapsed     | 1883     |
# |    total_timesteps  | 2785461  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0311   |
# |    n_updates        | 683863   |
# ----------------------------------

# %%
# import os
# import gym
# import torch as th
# from stable_baselines3 import DQN
# from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
# from stable_baselines3.common.callbacks import CheckpointCallback, EvalCallback
# from stable_baselines3.common.evaluation import evaluate_policy

# # ================== PATHS ==================
# LOG_DIR = "/content/drive/MyDrive/tetris_sb3_logs_V6"
# BEST_MODEL_PATH = os.path.join(LOG_DIR, "best_model", "best_model.zip")
# VECNORM_PATH = os.path.join(LOG_DIR, "vecnormalize.pkl")

# TOTAL_TIMESTEPS = 3_000_000
# RESUME_FROM = 1_000_000
# REMAINING_STEPS = TOTAL_TIMESTEPS - RESUME_FROM

# print(f"Resuming training for {REMAINING_STEPS:,} steps")

# # ================== LOAD TRAIN ENV ==================
# vec_env = DummyVecEnv([make_env()])
# vec_env = VecNormalize.load(VECNORM_PATH, vec_env)
# vec_env.training = True
# vec_env.norm_reward = False

# # ================== LOAD EVAL ENV ==================
# eval_env = DummyVecEnv([make_env()])
# eval_env = VecNormalize.load(VECNORM_PATH, eval_env)
# eval_env.training = False
# eval_env.norm_reward = False

# # 🔒 VERY IMPORTANT: sync normalization stats
# eval_env.obs_rms = vec_env.obs_rms

# # ================== LOAD MODEL ==================
# model = DQN.load(
#     BEST_MODEL_PATH,
#     env=vec_env,
#     tensorboard_log=LOG_DIR,
#     device="auto"
# )

# print("Resuming training from", model.num_time_steps)

# # ================== CALLBACKS ==================
# checkpoint_cb = CheckpointCallback(
#     save_freq=100_000,
#     save_path=os.path.join(LOG_DIR, "checkpoints"),
#     name_prefix="tetris_dqn"
# )

# eval_cb = EvalCallback(
#     eval_env,
#     best_model_save_path=os.path.join(LOG_DIR, "best_model"),
#     log_path=os.path.join(LOG_DIR, "eval_logs"),
#     eval_freq=50_000,
#     n_eval_episodes=8,
#     deterministic=True,
#     render=False,
#     callback_on_new_best=SaveVecNormalizeCallback(
#         save_path=os.path.join(LOG_DIR, "best_model")
#     )
# )

# save_vec_periodic = SaveVecNormalizeCallback(
#     save_path=os.path.join(LOG_DIR, "checkpoints"),
#     save_freq=100_000
# )

# # ================== RESUME TRAINING ==================
# model.learn(
#     total_timesteps=REMAINING_STEPS,
#     reset_num_timesteps=False,  # 🔑 CRITICAL
#     callback=[checkpoint_cb, eval_cb, save_vec_periodic]
# )

# # ================== FINAL SAVE ==================
# model.save(os.path.join(LOG_DIR, "tetris_dqn_final"))
# vec_env.save(os.path.join(LOG_DIR, "vecnormalize.pkl"))

# print("✅ Training resumed and completed.")

# # ================== QUICK EVAL ==================
# mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10)
# print(f"Eval mean reward: {mean_reward:.2f} ± {std_reward:.2f}")

# %%
import os
from stable_baselines3 import DQN
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize

# 1. Define the base path to your Drive folder
# Adjust 'Tetris_RL' if your logs are in a specific subfolder inside MyDrive
log_path = "/content/drive/MyDrive/tetris_sb3_logs_V6/"

# 2. Check if the file actually exists (Good for debugging)
vec_norm_path = os.path.join(log_path, "best_model/vecnormalize.pkl")
model_path = os.path.join(log_path, "best_model/best_model.zip") # .zip is often implicit in SB3, but good to be aware of

if not os.path.exists(vec_norm_path):
    print(f"Error: Could not find file at {vec_norm_path}")
    print("Available files in folder:", os.listdir(log_path))
else:
    # 3. Load the environment and model using the corrected paths

    # base env (assuming make_env is defined elsewhere in your code)
    dummy = DummyVecEnv([make_env()])

    # load normalization wrapper
    vec_env = VecNormalize.load(vec_norm_path, dummy)
    vec_env.training = False
    vec_env.norm_reward = False

    # load the trained model
    # Note: DQN.load handles the .zip extension automatically if omitted,
    # but the directory path must be correct.
    model = DQN.load(model_path, env=vec_env)

    print("Model loaded successfully!")

# %%
obs = vec_env.reset()
done = False
total_reward = 0
action_no=1

while not done:
    action, _ = model.predict(obs, deterministic=True)
    print(f"action {action_no}:", action)
    action_no+=1
    obs, reward, done, info = vec_env.step(action)
    print("reward", reward)
    total_reward += reward

    vec_env.envs[0].render()

print("Episode finished. Total reward:", total_reward)
print("Lines cleared:", info[0]['lines_cleared'])
